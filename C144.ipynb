# %% [markdown]
# # 1.4.4 Smoothing Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('messi5.jpg')

n=10
kernel = np.ones((n,n),np.float32)/(n*n)
dst = cv2.filter2D(img,-1,kernel)

#plt.rcParams["figure.figsize"] = (20,10)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('check.jpg')
n = 10
 #위의 세 줄과 같다.
#blur = cv2.blur(img,(n,n)) #전체를 같은 값으로...
#blur = cv2.GaussianBlur(img,(n,n),0)#노말분포 노이즈 없앨 때
#blur = cv2.medianBlur(img,5);#중앙값.노이즈 많을 때 작동 잘함 
blur = cv2.bilateralFilter(img,9,75,75) # 라인은 살아있고 내부만 블러처리. 라인이 살아나도록

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()
